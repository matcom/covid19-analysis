# %%
import json
import pandas as pd

with open("../data/timeseries.json") as fp:
    raw_data = json.load(fp)
    raw_dfs = {k: pd.DataFrame(v) for k,v in raw_data.items()}
    
    dfs = []
    for country, df in raw_dfs.items():
        df['date'] = pd.to_datetime(df['date'])
        df['week'] = df['date'].apply(lambda t: t.week)
        df['week'] = df['week'] - df['week'].min()
        df['new'] = df['confirmed'].diff().fillna(0)
        df = df.groupby('week').agg(confirmed=('confirmed', 'max'), new=('new', 'mean')).reset_index()
        df['country'] = country
        df = df[(df['confirmed'] > 10) & (df['new'] > 10)]
        dfs.append(df)
        
    raw_dfs = pd.concat(dfs)

# %%
raw_dfs
# Out:
#     week  confirmed        new             country
# 9      9        120  11.428571         Afghanistan
# 10    10        281  32.200000         Afghanistan
# 9      9        212  17.571429             Albania
# 10    10        304  18.400000             Albania
# 8      8        201  21.857143             Algeria
# ..   ...        ...        ...                 ...
# 9      9        144  14.428571          Uzbekistan
# 10    10        227  16.600000          Uzbekistan
# 9      9        188  10.714286             Vietnam
# 10    10        194  17.000000  West Bank and Gaza
# 9      9         94  13.428571              Kosovo
#
# [353 rows x 4 columns]

# %%
import altair as alt

totals = raw_dfs.groupby('country').agg(total=('confirmed', 'max'))
countries = list(totals.index[totals['total'] > 5000]) + ['Cuba']

# countries = ['US', 'Italy', 'China', 'Spain', 'France', 'United Kingdom', 'Germany', 'Cuba', 'Korea, South', 'Japan']
# countries = raw_data.keys()
data = raw_dfs[raw_dfs['country'].isin(countries)]

chart = alt.Chart(data).mark_line().encode(
    x=alt.X('confirmed', scale=alt.Scale(type='log')),
    y=alt.Y('new', scale=alt.Scale(type='log')),
    color='country',
    tooltip='country',
)
dots = alt.Chart(data).mark_point().encode(
    x=alt.X('confirmed', scale=alt.Scale(type='log')),
    y=alt.Y('new', scale=alt.Scale(type='log')),
    color='country',
)

text = chart.mark_text(align='left').encode(
    text='country'    
)

(chart + text + dots).properties(width=600, height=600).interactive()
# Out:
# alt.LayerChart(...)

# %%
responses = pd.read_csv("../data/responses.tsv", sep="\t").fillna("")
responses['Date'] = pd.to_datetime(responses['Date'], format="%d/%m/%Y", errors='coerce')
# responses['Day'] = responses['Date'] - '2020-01-01'
responses.head()
# Out:
#    ID      Country  ISO  Admin Code Region                      Category  \
# 0   1  Afghanistan  AFG               Asia        Public health measures
# 1   2  Afghanistan  AFG  Kabul        Asia        Public health measures
# 2   3  Afghanistan  AFG               Asia        Public health measures
# 3   4  Afghanistan  AFG               Asia  Social and economic measures
# 4   5  Afghanistan  AFG               Asia             Social distancing
#
#                                              Measure Pop. Targeted  \
# 0  Health screenings in airports and border cross...            No
# 1                Introduction of quarantine policies            No
# 2                                Awareness campaigns            No
# 3  Emergency administrative structures activated ...            No
# 4                            Limit public gatherings            No
#
#                     Comments Non-compliance       Date              Source  \
# 0                                           2020-02-12  Ministry of Health
# 1                                           2020-02-12  Ministry of Health
# 2                                           2020-02-12  Ministry of Health
# 3                                           2020-02-12  Ministry of Health
# 4  Nevruz festival cancelled                2020-03-12                  AA
#
#   Source Type
# 0  Government
# 1  Government
# 2  Government
# 3  Government
# 4       Media

# %%
alt.Chart(responses[responses['Country'].isin(countries)]).mark_line(size=0.25).encode(
    x='Date',
    y='Country',
    color='Region',
    shape='Category',
    size='count()',
    tooltip='Measure',
).properties(width=1000)
# Out:
# alt.Chart(...)
